# %% [markdown]
# # EDA Kaggle Competition: Team Integreat

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## SUMMARY
# - train dataset has 1460 rows and 81 variables
# - many variables have huge std, need to be adjusted?
# - `Alley, FireplaceQu, PoolQC, Fence, and MiscFeature` contained many NAs and have been dropped
# - `OverallQual and OverallCon` have been factorized
# - many outliers, need to be removed?
# - scatterplot and correlation matrix showed strongest correlation with total basement square feet and garage are

# %%
# test data has 80 variables and 1459 rows
# many missing values
# integers, floats, and objects

test = pd.read_csv('test.csv')
test.sample(50)
test.describe()

# %% [markdown]
# ## Inspecting numercial data

# %%
train = pd.read_csv('train.csv')
train.shape
# train dataset has 1460 rows and 81 variables

#inspecting mean and median
train.describe().loc[['mean','50%','std']]
# median 0 for MasVnrArea, BsmtFinSF2, 2ndFlrSF, WoodDeckSF, EnclosedPorch, MiscVal
# huge sd for LotArea, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, 2ndFlrSF, LowQualFinSF, Fireplaces,
#GarageArea, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal

train.sample(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 951    952          20       RH         60.0     7800   Pave   NaN      Reg
# 155    156          50       RL         60.0     9600   Pave   NaN      Reg
# 1266  1267         190       RM         60.0    10120   Pave   NaN      IR1
# 1065  1066          60       RL         80.0    14000   Pave   NaN      Reg
# 766    767          60       RL         80.0    10421   Pave   NaN      Reg
# 226    227          60       RL         82.0     9950   Pave   NaN      IR1
# 51      52          50       RM         52.0     6240   Pave   NaN      Reg
# 1260  1261          60       RL          NaN    24682   Pave   NaN      IR3
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 1203  1204          20       RL         75.0     9750   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %% [markdown]
# ## Missing values

# %%
# Alley, FireplaceQu, PoolQC, Fence, and MiscFeature can be probelamtic
pd.set_option('display.max_rows', train.shape[0])
np.sum(test.isnull(), axis = 0)
np.sum(test.isnull(), axis = 1)

# zero rows with any na
mask_column = test.isnull().any(axis=0) 
mask_row = test.isnull().any(axis=1)

#mask on rows and columns
test.loc[mask_row,mask_column]

#dropped above mentioned columns
test.drop(['FireplaceQu', 'PoolQC','Fence','MiscFeature'], axis=1, inplace=True)

# %% [markdown]
# ## Factorize columns

# %%
labels1, levels1 = pd.factorize(train.OverallQual)
labels2, levels2 = pd.factorize(train.OverallCond)
train.OverallQual = labels1
train.OverallCond = labels2

# %% [markdown]
# ## Outlier inspection due to large std

# %%
#MasVnArea throws error
outlier = ["BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF", "2ndFlrSF", "LowQualFinSF", "Fireplaces",
"WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch", "PoolArea"]

sns.pairplot(train[outlier])

# remove outliers from all?
#df[df.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]

# %% [markdown]
# ## Scatterplot for selected numerical columns

# %%
# investigate relationships
train.describe().columns
cols = ['LotArea','OverallQual','OverallCond','TotalBsmtSF','GarageArea', 'SalePrice']
sns.pairplot(train[cols], size=2)

#SalePrice right-skewed - log or box cox transformation
#TotalBsmtSF and GarageArea normally distributed

#Correlations SalePrice: TotalBsmtSF, GaraArea, OverallQual
#Multicollinearity: OverallQual and TotalBsmtSF, TotalBsmtSF and GarageArea

# %%
cor = np.corrcoef(train[cols].values.T)
sns.set(font_scale=1.5)
heat = sns.heatmap(cor, cbar=True,
                  annot=True,
                  square=True,
                  fmt='.2f',
                  annot_kws={'size':15},
                  yticklabels=cols,
                  xticklabels=cols)

#SalePrice correlate with: GarageArea, TotalSF
